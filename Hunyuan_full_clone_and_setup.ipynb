# %%
from jedi.api import file_name
# !git clone https://github.com/Tencent-Hunyuan/Hunyuan3D-2.git
# Out:
# Cloning into 'Hunyuan3D-2'...
# remote: Enumerating objects: 1070, done.
# remote: Counting objects: 100% (301/301), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 1070 (delta 234), reused 202 (delta 202), pack-reused 769 (from 3)(219/1070), 3.07 MiB | 1.51 MiB/sReceiving objects:  21% (225/1070), 5.93 MiB | 1.66 MiB/sReceiving objects:  21% (233/1070), 8.10 MiB | 1.77 MiB/sReceiving objects:  23% (247/1070), 10.51 MiB | 1.99 MiB/sReceiving objects:  24% (264/1070), 13.10 MiB | 2.19 MiB/sReceiving objects:  26% (279/1070), 15.71 MiB | 2.35 MiB/sReceiving objects:  27% (289/1070), 17.04 MiB | 2.42 MiB/sReceiving objects:  28% (300/1070), 19.18 MiB | 2.42 MiB/sReceiving objects:  29% (311/1070), 21.56 MiB | 2.13 MiB/sReceiving objects:  30% (329/1070), 26.32 MiB | 1.74 MiB/sReceiving objects:  30% (330/1070), 28.97 MiB | 1.62 MiB/sReceiving objects:  30% (330/1070), 32.27 MiB | 1.48 MiB/sReceiving objects:  30% (331/1070), 36.63 MiB | 1.83 MiB/sReceiving objects:  30% (331/1070), 40.70 MiB | 2.00 MiB/sReceiving objects:  31% (332/1070), 43.07 MiB | 1.91 MiB/sReceiving objects:  31% (334/1070), 47.52 MiB | 1.64 MiB/sReceiving objects:  32% (343/1070), 49.46 MiB | 1.75 MiB/sReceiving objects:  32% (343/1070), 52.59 MiB | 1.88 MiB/sReceiving objects:  32% (343/1070), 57.46 MiB | 2.17 MiB/sReceiving objects:  32% (343/1070), 62.84 MiB | 2.47 MiB/sReceiving objects:  32% (343/1070), 68.14 MiB | 2.62 MiB/sReceiving objects:  32% (343/1070), 73.39 MiB | 2.59 MiB/sReceiving objects:  34% (364/1070), 76.06 MiB | 2.59 MiB/sReceiving objects:  38% (407/1070), 76.06 MiB | 2.59 MiB/sReceiving objects:  48% (514/1070), 76.06 MiB | 2.59 MiB/sReceiving objects:  59% (632/1070), 77.35 MiB | 2.58 MiB/sReceiving objects:  60% (642/1070), 80.07 MiB | 2.60 MiB/sReceiving objects:  71% (762/1070), 80.07 MiB | 2.60 MiB/sReceiving objects:  73% (782/1070), 80.07 MiB | 2.60 MiB/sReceiving objects:  90% (963/1070), 80.07 MiB | 2.60 MiB/s
# Receiving objects: 100% (1070/1070), 81.29 MiB | 2.08 MiB/s, done.
# Resolving deltas: 100% (521/521), done.

# %%
# %cd Hunyuan3D-2/
# Out:
# /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2

# %%
# !pip install -r requirements.txt
# Out:
# Collecting ninja (from -r requirements.txt (line 1))
#   Using cached ninja-1.13.0-py3-none-macosx_10_9_universal2.whl.metadata (5.1 kB)
# Collecting pybind11 (from -r requirements.txt (line 2))
#   Using cached pybind11-3.0.1-py3-none-any.whl.metadata (10.0 kB)
# Collecting diffusers (from -r requirements.txt (line 4))
#   Using cached diffusers-0.35.2-py3-none-any.whl.metadata (20 kB)
# Collecting einops (from -r requirements.txt (line 5))
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python (from -r requirements.txt (line 6))
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting numpy (from -r requirements.txt (line 7))
#   Downloading numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting torch (from -r requirements.txt (line 8))
#   Downloading torch-2.9.1-cp312-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Collecting transformers (from -r requirements.txt (line 9))
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting torchvision (from -r requirements.txt (line 10))
#   Downloading torchvision-0.24.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting omegaconf (from -r requirements.txt (line 14))
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm (from -r requirements.txt (line 17))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting trimesh (from -r requirements.txt (line 20))
#   Using cached trimesh-4.9.0-py3-none-any.whl.metadata (18 kB)
# Collecting pymeshlab (from -r requirements.txt (line 21))
#   Using cached pymeshlab-2025.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting pygltflib (from -r requirements.txt (line 22))
#   Using cached pygltflib-1.16.5-py3-none-any.whl.metadata (33 kB)
# Collecting xatlas (from -r requirements.txt (line 23))
#   Using cached xatlas-0.0.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting accelerate (from -r requirements.txt (line 28))
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting gradio (from -r requirements.txt (line 34))
#   Using cached gradio-5.49.1-py3-none-any.whl.metadata (16 kB)
# Collecting fastapi (from -r requirements.txt (line 35))
#   Downloading fastapi-0.121.3-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn (from -r requirements.txt (line 36))
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting rembg (from -r requirements.txt (line 37))
#   Downloading rembg-2.0.68-py3-none-any.whl.metadata (17 kB)
# Collecting onnxruntime (from -r requirements.txt (line 38))
#   Using cached onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl.metadata (5.1 kB)
# Collecting importlib_metadata (from diffusers->-r requirements.txt (line 4))
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting filelock (from diffusers->-r requirements.txt (line 4))
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.34.0 (from diffusers->-r requirements.txt (line 4))
#   Downloading huggingface_hub-1.1.5-py3-none-any.whl.metadata (13 kB)
# Collecting regex!=2019.12.17 (from diffusers->-r requirements.txt (line 4))
#   Downloading regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from diffusers->-r requirements.txt (line 4)) (2.32.5)
# Collecting safetensors>=0.3.1 (from diffusers->-r requirements.txt (line 4))
#   Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting Pillow (from diffusers->-r requirements.txt (line 4))
#   Using cached pillow-12.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting numpy (from -r requirements.txt (line 7))
#   Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: setuptools in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 8)) (80.9.0)
# Collecting sympy>=1.13.3 (from torch->-r requirements.txt (line 8))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->-r requirements.txt (line 8))
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 8)) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch->-r requirements.txt (line 8))
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface-hub>=0.34.0 (from diffusers->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 9)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 9)) (6.0.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->-r requirements.txt (line 9))
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->-r requirements.txt (line 14))
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting dataclasses-json>=0.0.25 (from pygltflib->-r requirements.txt (line 22))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated (from pygltflib->-r requirements.txt (line 22))
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: psutil in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from accelerate->-r requirements.txt (line 28)) (7.1.3)
# Collecting aiofiles<25.0,>=22.0 (from gradio->-r requirements.txt (line 34))
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->-r requirements.txt (line 34)) (4.11.0)
# Collecting brotli>=1.1.0 (from gradio->-r requirements.txt (line 34))
#   Downloading brotli-1.2.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (6.1 kB)
# Collecting ffmpy (from gradio->-r requirements.txt (line 34))
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.13.3 (from gradio->-r requirements.txt (line 34))
#   Using cached gradio_client-1.13.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio->-r requirements.txt (line 34))
#   Using cached groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->-r requirements.txt (line 34)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->-r requirements.txt (line 34)) (3.0.3)
# Collecting orjson~=3.0 (from gradio->-r requirements.txt (line 34))
#   Downloading orjson-3.11.4-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting pandas<3.0,>=1.0 (from gradio->-r requirements.txt (line 34))
#   Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting Pillow (from diffusers->-r requirements.txt (line 4))
#   Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting pydantic<2.12,>=2.0 (from gradio->-r requirements.txt (line 34))
#   Using cached pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Collecting pydub (from gradio->-r requirements.txt (line 34))
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio->-r requirements.txt (line 34))
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio->-r requirements.txt (line 34))
#   Downloading ruff-0.14.5-py3-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio->-r requirements.txt (line 34))
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 34))
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio->-r requirements.txt (line 34))
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->-r requirements.txt (line 34))
#   Using cached tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio->-r requirements.txt (line 34))
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting websockets<16.0,>=13.0 (from gradio-client==1.13.3->gradio->-r requirements.txt (line 34))
#   Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->-r requirements.txt (line 35))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting click>=7.0 (from uvicorn->-r requirements.txt (line 36))
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: h11>=0.8 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from uvicorn->-r requirements.txt (line 36)) (0.16.0)
# Requirement already satisfied: jsonschema in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->-r requirements.txt (line 37)) (4.25.1)
# Collecting opencv-python-headless (from rembg->-r requirements.txt (line 37))
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting pooch (from rembg->-r requirements.txt (line 37))
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting pymatting (from rembg->-r requirements.txt (line 37))
#   Using cached pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Collecting scikit-image (from rembg->-r requirements.txt (line 37))
#   Using cached scikit_image-0.25.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting scipy (from rembg->-r requirements.txt (line 37))
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting coloredlogs (from onnxruntime->-r requirements.txt (line 38))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime->-r requirements.txt (line 38))
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime->-r requirements.txt (line 38))
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: idna>=2.8 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 34)) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 34)) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib->-r requirements.txt (line 22))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib->-r requirements.txt (line 22))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 34)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 34)) (1.0.9)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.34.0->diffusers->-r requirements.txt (line 4))
#   Downloading hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34))
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34)) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 34))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 34))
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 34))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->-r requirements.txt (line 8))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 34))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 34))
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->-r requirements.txt (line 38))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting wrapt<3,>=1.10 (from deprecated->pygltflib->-r requirements.txt (line 22))
#   Downloading wrapt-2.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers->-r requirements.txt (line 4))
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: attrs>=22.2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->-r requirements.txt (line 37)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->-r requirements.txt (line 37)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->-r requirements.txt (line 37)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->-r requirements.txt (line 37)) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pooch->rembg->-r requirements.txt (line 37)) (4.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from requests->diffusers->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from requests->diffusers->-r requirements.txt (line 4)) (2.5.0)
# Collecting numba!=0.49.0 (from pymatting->rembg->-r requirements.txt (line 37))
#   Using cached numba-0.62.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->rembg->-r requirements.txt (line 37))
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->rembg->-r requirements.txt (line 37))
#   Using cached tifffile-2025.10.16-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->rembg->-r requirements.txt (line 37))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba!=0.49.0->pymatting->rembg->-r requirements.txt (line 37))
#   Using cached llvmlite-0.45.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34)) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34))
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (2.19.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->-r requirements.txt (line 22))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached ninja-1.13.0-py3-none-macosx_10_9_universal2.whl (310 kB)
# Using cached pybind11-3.0.1-py3-none-any.whl (293 kB)
# Using cached diffusers-0.35.2-py3-none-any.whl (4.1 MB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Downloading torch-2.9.1-cp312-none-macosx_11_0_arm64.whl (74.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 2.7 MB/s eta 0:00:0000:0100:01
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Downloading torchvision-0.24.1-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached trimesh-4.9.0-py3-none-any.whl (736 kB)
# Using cached pymeshlab-2025.7-cp312-cp312-macosx_11_0_arm64.whl (73.8 MB)
# Using cached pygltflib-1.16.5-py3-none-any.whl (27 kB)
# Using cached xatlas-0.0.11-cp312-cp312-macosx_11_0_arm64.whl (201 kB)
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Using cached gradio-5.49.1-py3-none-any.whl (63.5 MB)
# Using cached gradio_client-1.13.3-py3-none-any.whl (325 kB)
# Downloading fastapi-0.121.3-py3-none-any.whl (109 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading rembg-2.0.68-py3-none-any.whl (43 kB)
# Using cached onnxruntime-1.23.2-cp312-cp312-macosx_13_0_arm64.whl (17.2 MB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp312-cp312-macosx_10_13_universal2.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.5/861.5 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 2.5 MB/s eta 0:00:00
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Downloading orjson-3.11.4-cp312-cp312-macosx_15_0_arm64.whl (128 kB)
# Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
# Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pydantic-2.11.10-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl (288 kB)
# Downloading ruff-0.14.5-py3-none-macosx_11_0_arm64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
# Using cached tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached pymatting-1.1.14-py3-none-any.whl (54 kB)
# Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 2.7 MB/s eta 0:00:0000:0100:01
# Using cached scikit_image-0.25.2-cp312-cp312-macosx_12_0_arm64.whl (13.2 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached numba-0.62.1-cp312-cp312-macosx_11_0_arm64.whl (2.7 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tifffile-2025.10.16-py3-none-any.whl (231 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Downloading wrapt-2.0.1-cp312-cp312-macosx_11_0_arm64.whl (61 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached llvmlite-0.45.1-cp312-cp312-macosx_11_0_arm64.whl (37.3 MB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, pydub, mpmath, flatbuffers, brotli, antlr4-python3-runtime, zipp, xatlas, wrapt, websockets, typing-inspection, tqdm, tomlkit, sympy, shellingham, semantic-version, safetensors, ruff, regex, python-multipart, pydantic-core, pybind11, protobuf, Pillow, orjson, omegaconf, numpy, ninja, networkx, mypy-extensions, mdurl, marshmallow, llvmlite, lazy-loader, humanfriendly, hf-xet, groovy, fsspec, filelock, ffmpy, einops, click, annotated-types, annotated-doc, aiofiles, uvicorn, typing-inspect, trimesh, torch, tifffile, starlette, scipy, pymeshlab, pydantic, pooch, pandas, opencv-python-headless, opencv-python, numba, markdown-it-py, importlib_metadata, imageio, huggingface-hub, deprecated, coloredlogs, torchvision, tokenizers, scikit-image, safehttpx, rich, pymatting, onnxruntime, gradio-client, fastapi, diffusers, dataclasses-json, accelerate, typer, transformers, rembg, pygltflib, gradio
# Successfully installed Pillow-11.3.0 accelerate-1.11.0 aiofiles-24.1.0 annotated-doc-0.0.4 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 brotli-1.2.0 click-8.3.1 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.3.1 diffusers-0.35.2 einops-0.8.1 fastapi-0.121.3 ffmpy-1.0.0 filelock-3.20.0 flatbuffers-25.9.23 fsspec-2025.10.0 gradio-5.49.1 gradio-client-1.13.3 groovy-0.1.2 hf-xet-1.2.0 huggingface-hub-0.36.0 humanfriendly-10.0 imageio-2.37.2 importlib_metadata-8.7.0 lazy-loader-0.4 llvmlite-0.45.1 markdown-it-py-4.0.0 marshmallow-3.26.1 mdurl-0.1.2 mpmath-1.3.0 mypy-extensions-1.1.0 networkx-3.5 ninja-1.13.0 numba-0.62.1 numpy-2.2.6 omegaconf-2.3.0 onnxruntime-1.23.2 opencv-python-4.12.0.88 opencv-python-headless-4.12.0.88 orjson-3.11.4 pandas-2.3.3 pooch-1.8.2 protobuf-6.33.1 pybind11-3.0.1 pydantic-2.11.10 pydantic-core-2.33.2 pydub-0.25.1 pygltflib-1.16.5 pymatting-1.1.14 pymeshlab-2025.7 python-multipart-0.0.20 pytz-2025.2 regex-2025.11.3 rembg-2.0.68 rich-14.2.0 ruff-0.14.5 safehttpx-0.1.7 safetensors-0.7.0 scikit-image-0.25.2 scipy-1.16.3 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.50.0 sympy-1.14.0 tifffile-2025.10.16 tokenizers-0.22.1 tomlkit-0.13.3 torch-2.9.1 torchvision-0.24.1 tqdm-4.67.1 transformers-4.57.1 trimesh-4.9.0 typer-0.20.0 typing-inspect-0.9.0 typing-inspection-0.4.2 uvicorn-0.38.0 websockets-15.0.1 wrapt-2.0.1 xatlas-0.0.11 zipp-3.23.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: gradio in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (5.49.1)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (4.67.1)
# Requirement already satisfied: numpy in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (2.2.6)
# Requirement already satisfied: ninja in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (1.13.0)
# Requirement already satisfied: diffusers in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (0.35.2)
# Requirement already satisfied: pybind11 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (3.0.1)
# Requirement already satisfied: opencv-python in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (4.12.0.88)
# Requirement already satisfied: einops in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (0.8.1)
# Requirement already satisfied: transformers>=4.48.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (4.57.1)
# Requirement already satisfied: omegaconf in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (2.3.0)
# Requirement already satisfied: trimesh in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (4.9.0)
# Requirement already satisfied: pymeshlab in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (2025.7)
# Requirement already satisfied: pygltflib in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (1.16.5)
# Requirement already satisfied: xatlas in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (0.0.11)
# Requirement already satisfied: accelerate in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (1.11.0)
# Requirement already satisfied: fastapi in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (0.121.3)
# Requirement already satisfied: uvicorn in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (0.38.0)
# Requirement already satisfied: rembg in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (2.0.68)
# Requirement already satisfied: onnxruntime in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from hy3dgen==2.0.2) (1.23.2)
# Requirement already satisfied: filelock in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (2025.11.3)
# Requirement already satisfied: requests in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.7.0)
# Requirement already satisfied: psutil in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from accelerate->hy3dgen==2.0.2) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from accelerate->hy3dgen==2.0.2) (2.9.1)
# Requirement already satisfied: importlib_metadata in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from diffusers->hy3dgen==2.0.2) (8.7.0)
# Requirement already satisfied: Pillow in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from diffusers->hy3dgen==2.0.2) (11.3.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from fastapi->hy3dgen==2.0.2) (0.50.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from fastapi->hy3dgen==2.0.2) (2.11.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from fastapi->hy3dgen==2.0.2) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from fastapi->hy3dgen==2.0.2) (0.0.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (1.2.0)
# Requirement already satisfied: ffmpy in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.3 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (3.11.4)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (2.3.3)
# Requirement already satisfied: pydub in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio->hy3dgen==2.0.2) (0.20.0)
# Requirement already satisfied: fsspec in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio-client==1.13.3->gradio->hy3dgen==2.0.2) (2025.10.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from gradio-client==1.13.3->gradio->hy3dgen==2.0.2) (15.0.1)
# Requirement already satisfied: click>=7.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from uvicorn->hy3dgen==2.0.2) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from uvicorn->hy3dgen==2.0.2) (0.16.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from omegaconf->hy3dgen==2.0.2) (4.9.3)
# Requirement already satisfied: coloredlogs in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from onnxruntime->hy3dgen==2.0.2) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from onnxruntime->hy3dgen==2.0.2) (25.9.23)
# Requirement already satisfied: protobuf in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from onnxruntime->hy3dgen==2.0.2) (6.33.1)
# Requirement already satisfied: sympy in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from onnxruntime->hy3dgen==2.0.2) (1.14.0)
# Requirement already satisfied: dataclasses-json>=0.0.25 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pygltflib->hy3dgen==2.0.2) (0.6.7)
# Requirement already satisfied: deprecated in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pygltflib->hy3dgen==2.0.2) (1.3.1)
# Requirement already satisfied: jsonschema in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (4.25.1)
# Requirement already satisfied: opencv-python-headless in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (4.12.0.88)
# Requirement already satisfied: pooch in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (1.8.2)
# Requirement already satisfied: pymatting in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (1.1.14)
# Requirement already satisfied: scikit-image in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (0.25.2)
# Requirement already satisfied: scipy in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rembg->hy3dgen==2.0.2) (1.16.3)
# Requirement already satisfied: idna>=2.8 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio->hy3dgen==2.0.2) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio->hy3dgen==2.0.2) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2) (0.9.0)
# Requirement already satisfied: certifi in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio->hy3dgen==2.0.2) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio->hy3dgen==2.0.2) (1.0.9)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.48.0->hy3dgen==2.0.2) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (0.4.2)
# Requirement already satisfied: setuptools in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (80.9.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from sympy->onnxruntime->hy3dgen==2.0.2) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (14.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime->hy3dgen==2.0.2) (10.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from deprecated->pygltflib->hy3dgen==2.0.2) (2.0.1)
# Requirement already satisfied: zipp>=3.20 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from importlib_metadata->diffusers->hy3dgen==2.0.2) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->hy3dgen==2.0.2) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->hy3dgen==2.0.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->hy3dgen==2.0.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from jsonschema->rembg->hy3dgen==2.0.2) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pooch->rembg->hy3dgen==2.0.2) (4.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from requests->transformers>=4.48.0->hy3dgen==2.0.2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from requests->transformers>=4.48.0->hy3dgen==2.0.2) (2.5.0)
# Requirement already satisfied: numba!=0.49.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from pymatting->rembg->hy3dgen==2.0.2) (0.62.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from scikit-image->rembg->hy3dgen==2.0.2) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from scikit-image->rembg->hy3dgen==2.0.2) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from scikit-image->rembg->hy3dgen==2.0.2) (0.4)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from numba!=0.49.0->pymatting->rembg->hy3dgen==2.0.2) (0.45.1)
# Requirement already satisfied: six>=1.5 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (2.19.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2) (1.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (0.1.2)
# Building wheels for collected packages: hy3dgen
#   Building editable for hy3dgen (pyproject.toml) ... done
#   Created wheel for hy3dgen: filename=hy3dgen-2.0.2-0.editable-py3-none-any.whl size=20113 sha256=22a9c3348450848e4d7f720bc31bad7790ed4bd6f46789d14886e8684125b0d8
#   Stored in directory: /private/var/folders/94/b_3tvyjd77b_h_t3g79sy0480000gn/T/pip-ephem-wheel-cache-pt2sb0hr/wheels/4b/36/02/fd4918839c142b0bd7e6f742456ba6e89f417170903e8af5f1
# Successfully built hy3dgen
# Installing collected packages: hy3dgen
# Successfully installed hy3dgen-2.0.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# %cd hy3dgen/texgen/custom_rasterizer
# Out:
# /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer

# %%
# !python setup.py install
# Out:
# Traceback (most recent call last):
#   File "/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/setup.py", line 8, in <module>
#     custom_rasterizer_module = CUDAExtension('custom_rasterizer_kernel', [
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 1347, in CUDAExtension
#     library_dirs += library_paths(device_type="cuda")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 1559, in library_paths
#     if (not os.path.exists(_join_cuda_home(lib_dir)) and
#                            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 2986, in _join_cuda_home
#     raise OSError('CUDA_HOME environment variable is not set. '
# OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.

# %%
# %cd ../../..
# Out:
# /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2

# %%
# %cd hy3dgen/texgen/differentiable_renderer
# !python setup.py install
# Out:
# /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/Hunyuan3D-2/hy3dgen/texgen/differentiable_renderer
# running install
# /Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/setuptools/_distutils/cmd.py:90: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         This deprecation is overdue, please update your project and remove deprecated
#         calls to avoid build errors in the future.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running build
# running build_ext
# building 'mesh_processor' extension
# creating build/temp.macosx-10.13-universal2-cpython-312
# clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/pybind11/include -I/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/lib/python3.12/site-packages/pybind11/include -I/Users/divyanshudevawasthi/PycharmProjects/chibi-chitra/.venv/include -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c mesh_processor.cpp -o build/temp.macosx-10.13-universal2-cpython-312/mesh_processor.o -O3 -std=c++14 -fPIC -Wall -Wextra -stdlib=libc++ -mmacosx-version-min=10.14
# creating build/lib.macosx-10.13-universal2-cpython-312
# clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/mesh_processor.o -o build/lib.macosx-10.13-universal2-cpython-312/mesh_processor.cpython-312-darwin.so -fPIC -stdlib=libc++ -mmacosx-version-min=10.14 -dynamiclib
# clang++: error: invalid argument '-bundle' not allowed with '-dynamiclib'
# clang++: error: invalid argument '-bundle' not allowed with '-dynamiclib'
# error: command '/usr/bin/clang++' failed with exit code 1

# %%
# %cd /content/Hunyuan3D-2/
# !pip install .
